# %% [markdown]
# part 1 & 2: IMPORT and INITIALIZE

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master("local[2]") \
    .appName("bigdata") \
    .config("spark.driver.host", "127.0.0.1") \
    .config("spark.driver.bindAddress", "127.0.0.1") \
    .getOrCreate()

print("Ready:", spark.version, "Ready")
# Out:
# Ready: 4.1.1 Ready

# %% [markdown]
# step 3: LOAD DATASET

# %%
# with pandas 
import pandas as pd 
import time
import numpy as np
start=time.time()
df_pd=pd.read_csv(r"D:\6th SEMESTER\IT-506 Big Data Ali usama\student_performance_prediction_dataset-2.csv")
end=time.time()
print(f"pandas load time: {end-start:.2f} seconds") 

#with spark
start=time.time()
df = spark.read.csv(r"D:\6th SEMESTER\IT-506 Big Data Ali usama\student_performance_prediction_dataset-2.csv",
                    header=True,
                    inferSchema=True)
end=time.time()
print(f"spark load time: {end-start:.2f} seconds")
# Out:
# pandas load time: 2.73 seconds
# spark load time: 4.95 seconds
