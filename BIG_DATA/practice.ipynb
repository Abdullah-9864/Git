# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("taxi_zone_lookup").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://probook-g5.mshome.net:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>NYC Taxi Big Data Lab</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pandas as pd
pd_df = pd.read_csv("taxi_zone_lookup.csv")
print(pd_df.head())
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
import os
print(os.getcwd())  # Shows Python's current directory
print("Files in current directory:", os.listdir())
# Out:
# c:\Git\BIG_DATA
# Files in current directory: ['practice.ipynb', 'taxi_zone_lookup.csv', '__pycache__']
