# %% [markdown]
# Mutable and Immutable

# %%
a=12
b=a
print(a)
print(b)
a=23
print(a)
print(b)
# Out:
# 12
# 12
# 23
# 12

# %%
list=[12,34,345]
print(id(list))
list[2]=45
print(list)
print(len(list))
print(id(list))
# Out:
# 2609414471936
# [12, 34, 45]
# 3
# 2609414471936

# %% [markdown]
# Data Types
