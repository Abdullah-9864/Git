# %%
t=(1,2,3,4,5,5)   
print(type(t))
print(t)

thisSet={"apple", "banana", "cherry","apple"}
print(type(thisSet))
print(thisSet)

myList=[1,2,3,4,5,5]
print(type(myList))
print(myList)


myDict={"name":"John", "name":"John", "age":30, "city":"New York"}
print(type(myDict))
print(myDict)
print(myDict["name"])
myDict["age"]=31
print(myDict["age"])
print(myDict.get("name"))
print(myDict)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5, 5)
# <class 'set'>
# {'banana', 'apple', 'cherry'}
# <class 'list'>
# [1, 2, 3, 4, 5, 5]
# <class 'dict'>
# {'name': 'John', 'age': 30, 'city': 'New York'}
# John
# 31
# John
# {'name': 'John', 'age': 31, 'city': 'New York'}

# %%
def myFunction(food):
    for x in food:
        print(x)

fruits=["apple", "banana", "cherry"]
myFunction(fruits)
# Out:
# apple
# banana
# cherry

# %%
class myClass:
    x=5
p1=myClass()
print(p1.x)
# Out:
# 5
